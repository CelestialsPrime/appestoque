# %%
# !pip install git-filter-repo

# %%
# !git filter-repo --path estoque-988b9-firebase-adminsdk-fbsvc-6571d072e0.json --invert-paths --force
# Out:
# NOTICE: Removing 'origin' remote; see 'Why is my origin removed?'
#         in the manual if you want to push back there.
#         (was https://github.com/CelestialsPrime/appestoque.git)
#
# Parsed 2 commits
# New history written in 0.11 seconds; now repacking/cleaning...
# Repacking your repo and cleaning out old unneeded objects
# HEAD is now at 7ac8a15 Primeiro commit
# Completely finished after 0.37 seconds.

# %%
with open('.gitignore', 'a') as f:
    f.write('\nestoque-988b9-firebase-adminsdk-fbsvc-6571d072e0.json\n')

# %%
# !git add .
# !git commit -m "Removendo arquivo com chave secreta do histórico"
# !git push origin main --force
